# %% [markdown]
# # Week 6 - Bivariate Analysis, part 2

# %% [markdown]
# # 1. Lesson: no lesson this week

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you wanted to show the nitrate and phosphate level in a water sample.  What are the advantages and disadvantages of showing this as an area plot, as opposed to two separate line graphs?  How would you adjust the graphs shown to improve the presentation?

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# /tmp/ipykernel_5971/2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series_2 =  100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series_2)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# /tmp/ipykernel_5971/1726504607.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
df = pd.DataFrame({'ser1': time_series, 'ser2': time_series_2}, index = datearray)
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do:
#
# - Find correlations between pairs of variables.
#
# - Draw scatterplots, especially when the correlation is large.
#
# - Draw pairplots.
#
# - Draw line graphs and/or area graphs when there is date or time data together with numerical data.
#
# ### Conclusions:
#
# - Explain what conclusions you would draw from this analysis: are the data what you expect?  Are the data likely to be usable?  If the data are not useable, find some new data!
#
# - Do you see any outliers?  (Data points that are far from the rest of the data).
#
# - Are any data items highly correlated with each other, suggesting that they are redundant?
#
# - For the line plots, do you see a trend or pattern over time?  Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
#
# - Can you think of any confounding variables?  (Third variables that could explain any correlations between other variables.  These third variables may or may not be reported in the dataset.)

# %% [markdown]
# Conclusions:
# I am suprised at how low the correlation is among many of the features.  I was expecting a higer correlation between price and size of the house or zipcode.  I think the correlation between garage spaces and parking spaces is redundant.  There is strong correlation between school ranking and median students per teacher and while that makes sense I'm not sure that it is relavent to the overall analysis in terms of property value espcially in light of short term rentals.
#
# There may be an unobserved variable, like a surge in people moving to the area, that is driving changes in price but is not captured in the features present in this dataset. This data is also captured in 2021 and the impacts of the COVID-19 pandemic could be a latent variable for the listings from 2020 and 2021.  New build vs. resale of an existing home could be a counfounding variable here as well(the USA real estate data set does have that feature).

# %%
austin_data = pd.read_csv("austinHousingData.csv")
austin_data
# Out:
#              zpid          city                   streetAddress  zipcode  \
# 0       111373431  pflugerville            14424 Lake Victor Dr    78660
# 1       120900430  pflugerville              1104 Strickling Dr    78660
# 2      2084491383  pflugerville             1408 Fort Dessau Rd    78660
# 3       120901374  pflugerville              1025 Strickling Dr    78660
# 4        60134862  pflugerville           15005 Donna Jane Loop    78660
# ...           ...           ...                             ...      ...
# 15166    29512934        austin                 905 Silcantu Dr    78748
# 15167   241937773        austin  1413 Waterloo Shore Ln UNIT 12    78741
# 15168    29473281        austin                   2206 S 3rd St    78704
# 15169    29392029        austin               2000 Chestnut Ave    78722
# 15170    29390174        austin                  3110 E 12th St    78702
#
#                                              description   latitude  \
# ...

# %%
austin_data_numeric = austin_data.select_dtypes(include=['number'])
austin_data_numeric
# Out:
#              zpid  zipcode   latitude  longitude  propertyTaxRate  \
# 0       111373431    78660  30.430632 -97.663078             1.98
# 1       120900430    78660  30.432673 -97.661697             1.98
# 2      2084491383    78660  30.409748 -97.639771             1.98
# 3       120901374    78660  30.432112 -97.661659             1.98
# 4        60134862    78660  30.437368 -97.656860             1.98
# ...           ...      ...        ...        ...              ...
# 15166    29512934    78748  30.161997 -97.816345             1.98
# 15167   241937773    78741  30.240223 -97.772835             1.98
# 15168    29473281    78704  30.244835 -97.761124             1.98
# 15169    29392029    78722  30.281569 -97.717789             1.98
# 15170    29390174    78702  30.276930 -97.701523             1.98
#
#        garageSpaces  parkingSpaces  yearBuilt  latestPrice  numPriceChanges  \
# 0                 2              2       2012     305000.0                5
# ...

# %%
austin_data_mini = austin_data_numeric[['zipcode', 'yearBuilt', 'latestPrice', 'latest_saleyear', 'livingAreaSqFt', 'numOfBathrooms', 'numOfBedrooms']]
austin_data_mini
# Out:
#        zipcode  yearBuilt  latestPrice  latest_saleyear  livingAreaSqFt  \
# 0        78660       2012     305000.0             2019          2601.0
# 1        78660       2013     295000.0             2020          1768.0
# 2        78660       2018     256125.0             2019          1478.0
# 3        78660       2013     240000.0             2018          1678.0
# 4        78660       2002     239900.0             2018          2132.0
# ...        ...        ...          ...              ...             ...
# 15166    78748       1986     330000.0             2020          1234.0
# 15167    78741       2016     550000.0             2020          1888.0
# 15168    78704       1936     875000.0             2021          1524.0
# 15169    78722       1968     420000.0             2019          6068.0
# 15170    78702       1955     374900.0             2021           720.0
#
#        numOfBathrooms  numOfBedrooms
# 0                 3.0              4
# ...

# %%
sns.pairplot(austin_data_mini)

# %%
print("Correlations:", austin_data_numeric.corr())
# Out:
# Correlations:                                 zpid   zipcode  latitude  longitude  \
# zpid                        1.000000 -0.052805 -0.055352   0.005886
# zipcode                    -0.052805  1.000000 -0.036440  -0.126135
# latitude                   -0.055352 -0.036440  1.000000   0.347597
# longitude                   0.005886 -0.126135  0.347597   1.000000
# propertyTaxRate            -0.011396 -0.172846  0.450187  -0.013746
# garageSpaces               -0.001927 -0.016600  0.019153  -0.115317
# parkingSpaces              -0.001410 -0.016687  0.018222  -0.114713
# yearBuilt                   0.213280 -0.016143 -0.116519  -0.252537
# latestPrice                 0.007503 -0.145946  0.071547  -0.184079
# numPriceChanges            -0.049541 -0.043115  0.013402  -0.050127
# latest_salemonth            0.012119  0.000116 -0.001667  -0.004023
# latest_saleyear             0.053438 -0.011057 -0.042536  -0.018003
# numOfPhotos                -0.012489 -0.011971  0.046059  -0.107296
# ...

# %%
corr_matrix = austin_data_numeric.corr()
high_corr = corr_matrix[corr_matrix.abs() > 0.7]
high_corr
# Out:
#                             zpid  zipcode  latitude  longitude  \
# zpid                         1.0      NaN       NaN        NaN
# zipcode                      NaN      1.0       NaN        NaN
# latitude                     NaN      NaN       1.0        NaN
# longitude                    NaN      NaN       NaN        1.0
# propertyTaxRate              NaN      NaN       NaN        NaN
# garageSpaces                 NaN      NaN       NaN        NaN
# parkingSpaces                NaN      NaN       NaN        NaN
# yearBuilt                    NaN      NaN       NaN        NaN
# latestPrice                  NaN      NaN       NaN        NaN
# numPriceChanges              NaN      NaN       NaN        NaN
# latest_salemonth             NaN      NaN       NaN        NaN
# latest_saleyear              NaN      NaN       NaN        NaN
# numOfPhotos                  NaN      NaN       NaN        NaN
# numOfAccessibilityFeatures   NaN      NaN       NaN        NaN
# ...

# %%
high_corr_clean = high_corr.dropna(how="all")
high_corr_clean
# Out:
#                             zpid  zipcode  latitude  longitude  \
# zpid                         1.0      NaN       NaN        NaN
# zipcode                      NaN      1.0       NaN        NaN
# latitude                     NaN      NaN       1.0        NaN
# longitude                    NaN      NaN       NaN        1.0
# propertyTaxRate              NaN      NaN       NaN        NaN
# garageSpaces                 NaN      NaN       NaN        NaN
# parkingSpaces                NaN      NaN       NaN        NaN
# yearBuilt                    NaN      NaN       NaN        NaN
# latestPrice                  NaN      NaN       NaN        NaN
# numPriceChanges              NaN      NaN       NaN        NaN
# latest_salemonth             NaN      NaN       NaN        NaN
# latest_saleyear              NaN      NaN       NaN        NaN
# numOfPhotos                  NaN      NaN       NaN        NaN
# numOfAccessibilityFeatures   NaN      NaN       NaN        NaN
# ...

# %%
sns.scatterplot(x= austin_data_numeric['MedianStudentsPerTeacher'], y= austin_data_numeric['avgSchoolRating'])
# Out:
# <Axes: xlabel='MedianStudentsPerTeacher', ylabel='avgSchoolRating'>

# %%
sns.scatterplot(x= austin_data_numeric['parkingSpaces'], y= austin_data_numeric['garageSpaces'])
# Out:
# <Axes: xlabel='parkingSpaces', ylabel='garageSpaces'>

# %%
sns.lineplot(x= austin_data['latest_saledate'], y= austin_data['latestPrice'])
# Out:
# <Axes: xlabel='latest_saledate', ylabel='latestPrice'>

# %%
austin_data_area = austin_data[['livingAreaSqFt','latestPrice','latest_saledate' ]]
austin_data_area
# Out:
#        livingAreaSqFt  latestPrice latest_saledate
# 0              2601.0     305000.0      2019-09-02
# 1              1768.0     295000.0      2020-10-13
# 2              1478.0     256125.0      2019-07-31
# 3              1678.0     240000.0      2018-08-08
# 4              2132.0     239900.0      2018-10-31
# ...               ...          ...             ...
# 15166          1234.0     330000.0      2020-12-10
# 15167          1888.0     550000.0      2020-12-16
# 15168          1524.0     875000.0      2021-01-27
# 15169          6068.0     420000.0      2019-08-07
# 15170           720.0     374900.0      2021-01-23
#
# [15171 rows x 3 columns]

# %%
austin_data_area.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 86-98 of the Storytelling With Data book as best you can.  (The second half of chapter three).  You do not have to get the exact data values right, just the overall look and feel.
